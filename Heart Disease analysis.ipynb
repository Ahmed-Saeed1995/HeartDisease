# %% [markdown]
# # <span style="color:red"> ❤️ Heart Disease Analysis</span>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
sns.set(rc={"figure.figsize":[4, 4]})

# %%
df = pd.read_csv('heart_2020_cleaned.csv')
df.shape
# Out:
# (319795, 18)

# %%
df.head(3)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No
# 2              Yes       Fair        8.0    Yes            No         No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
df.isnull().sum() -> No null data

# %%
df.head(2)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No

# %%
f, ax = plt.subplots(nrows=3, ncols =3, figsize=(15, 15))

plt.sca(ax[0][0])
sns.countplot(df["Smoking"], hue=df["HeartDisease"], palette="cool")
# ---------------------------------------
plt.sca(ax[0][1])
sns.countplot(df["Stroke"], hue=df["HeartDisease"], palette="cool")
# ---------------------------------------
plt.sca(ax[0][2])
sns.countplot(df["AlcoholDrinking"],hue=df["HeartDisease"], palette="cool")
# ---------------------------------------
plt.sca(ax[1][0])
sns.countplot(df["PhysicalActivity"],hue=df["HeartDisease"], palette="cool")
# ---------------------------------------
plt.sca(ax[1][1])
sns.countplot(df["Sex"],hue=df["HeartDisease"], palette="cool")
# # ---------------------------------------
plt.sca(ax[1][2])
sns.countplot(df["Asthma"],hue=df["HeartDisease"], palette="cool")
# ---------------------------------------
plt.sca(ax[2][0])
sns.countplot(y = df["Diabetic"],hue=df["HeartDisease"], palette="cool")
# ---------------------------------------
plt.sca(ax[2][1])
sns.countplot(df["KidneyDisease"],hue=df["HeartDisease"], palette="cool")
# ---------------------------------------
plt.sca(ax[2][2])
sns.countplot(df["SkinCancer"],hue=df["HeartDisease"], palette="cool")

# %%
plt.figure(figsize=(10, 10))
# df[df["SkinCancer"] == 'Yes']["AgeCategory"].hist()
# df[df["SkinCancer"] == 'Yes']["Race"].hist()
sns.countplot(df[df["SkinCancer"] == 'Yes']["AgeCategory"],hue=df["HeartDisease"], palette="cool")

# %%
plt.figure(figsize=(10, 10))
# df[df["KidneyDisease"] == 'Yes']["AgeCategory"].hist()
# df[df["KidneyDisease"] == 'Yes']["Race"].hist()
sns.countplot(df[df["KidneyDisease"] == 'Yes']["AgeCategory"],hue=df["HeartDisease"], palette="cool")

# %%
plt.figure(figsize=(10, 10))
# df[df["Diabetic"] == 'Yes']["AgeCategory"].hist()
sns.countplot(df[df["Diabetic"] == 'Yes']["AgeCategory"],hue=df["HeartDisease"], palette="cool")

# %%
plt.figure(figsize=(10, 10))
# df[df["Asthma"] == 'Yes']["AgeCategory"].hist()
sns.countplot(df[df["Asthma"] == 'Yes']["AgeCategory"],hue=df["HeartDisease"], palette="cool")

# %%
plt.figure(figsize=(10, 10))
sns.countplot(df[df["Asthma"] == 'Yes']["AgeCategory"],hue=df["HeartDisease"], palette="cool")

# %%
plt.figure(figsize=(10, 10))
sns.countplot(df[df["Stroke"] == 'No']["PhysicalActivity"],hue=df["HeartDisease"], palette="cool")

# %%
plt.figure(figsize=(10, 10))
sns.countplot(y = df[df["Stroke"] == 'No']["MentalHealth"],hue=df["HeartDisease"], palette="cool")

# %%
_, ax = plt.subplots(1, 2, figsize = (15,5))
plt.sca(ax[0])
sns.countplot(df["HeartDisease"], hue=df["GenHealth"], palette="cool")

plt.sca(ax[1])
sns.countplot(df["HeartDisease"], hue=df["Sex"], palette="cool")
plt.show()

# %%
plt.figure(figsize=(9, 5))
sns.countplot(y =  df["AgeCategory"], hue = df["Diabetic"])

# %%
f, ax = plt.subplots(nrows=3, ncols =3, figsize=(15, 15))

plt.sca(ax[0][0])
sns.countplot( y=df["AgeCategory"], hue=df["Smoking"], palette="cool")
# ---------------------------------------
plt.sca(ax[0][1])
sns.countplot(y=df["AgeCategory"], hue= df["Stroke"], palette="cool")
# ---------------------------------------
plt.sca(ax[0][2])
sns.countplot(y=df["AgeCategory"],hue= df["AlcoholDrinking"], palette="cool")
# ---------------------------------------
plt.sca(ax[1][0])
sns.countplot(y=df["AgeCategory"], hue  = df["PhysicalActivity"], palette="cool")
# ---------------------------------------
plt.sca(ax[1][1])
sns.countplot(y=df["AgeCategory"], hue= df["Sex"],palette="cool")
# # ---------------------------------------
plt.sca(ax[1][2])
sns.countplot(y=df["AgeCategory"], hue = df["Asthma"], palette="cool")
# ---------------------------------------
plt.sca(ax[2][0])
sns.countplot(y=df["AgeCategory"], hue=  df["Diabetic"], palette="cool")
# ---------------------------------------
plt.sca(ax[2][1])
sns.countplot(y=df["AgeCategory"], hue= df["KidneyDisease"], palette="cool")
# ---------------------------------------
plt.sca(ax[2][2])
sns.countplot(y=df["AgeCategory"] , hue= df["SkinCancer"],palette="cool")

# %%
sns.countplot( y=df["HeartDisease"], hue=df["DiffWalking"], palette="cool")

# %%
f, ax = plt.subplots(nrows=3, ncols =3, figsize=(15, 15))

plt.sca(ax[0][0])
sns.countplot( y=df["SleepTime"], hue=df["Smoking"], palette="cool")
# ---------------------------------------
plt.sca(ax[0][1])
sns.countplot(y=df["SleepTime"], hue= df["Stroke"], palette="cool")
# ---------------------------------------
plt.sca(ax[0][2])
sns.countplot(y=df["SleepTime"],hue= df["AlcoholDrinking"], palette="cool")
# ---------------------------------------
plt.sca(ax[1][0])
sns.countplot(y=df["SleepTime"], hue  = df["PhysicalActivity"], palette="cool")
# ---------------------------------------
plt.sca(ax[1][1])
sns.countplot(y=df["SleepTime"], hue= df["Sex"],palette="cool")
# # ---------------------------------------
plt.sca(ax[1][2])
sns.countplot(y=df["SleepTime"], hue = df["Asthma"], palette="cool")
# ---------------------------------------
plt.sca(ax[2][0])
sns.countplot(y=df["SleepTime"], hue=  df["Diabetic"], palette="cool")
# ---------------------------------------
plt.sca(ax[2][1])
sns.countplot(y=df["SleepTime"], hue= df["KidneyDisease"], palette="cool")
# ---------------------------------------
plt.sca(ax[2][2])
sns.countplot(y=df["SleepTime"] , hue= df["SkinCancer"],palette="cool")

# %%
df[df["BMI"] == df["BMI"].max()]
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 126896           No  94.85      No              No     No             0.0
#
#         MentalHealth DiffWalking   Sex AgeCategory   Race Diabetic  \
# 126896           0.0          No  Male       35-39  White       No
#
#        PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 126896              Yes  Excellent        7.0     No            No         No

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(df["PhysicalHealth"], df["MentalHealth"], color="green")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y = df["AgeCategory"],hue = df["HeartDisease"])
# as age increase the HeartDisease causes some are healthy

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y = df["Race"],hue = df["HeartDisease"])
# as age increase the HeartDisease causes some are healthy
# الاطثر صحة البيض: الاكثر اعراق مصابين بالقلب البيض وقليل جدا السود

# %%
_, ax = plt.subplots(1, 2, figsize=(15, 4))
plt.sca(ax[0])
sns.stripplot(df["HeartDisease"], df["BMI"])

plt.sca(ax[1])
sns.stripplot( df["BMI"], df["Diabetic"] , palette="cool", dodge = True)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot( df["SleepTime"] , df["BMI"])

# %%
plt.figure(figsize=(10, 6))
sns.countplot( y = df["SleepTime"], hue= df["GenHealth"], palette="cool")

# %%
sns.countplot( df["GenHealth"], hue= df["HeartDisease"], palette="cool")

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(18, 6))
# sns.distplot(df["SleepTime"])
sns.distplot(df["PhysicalHealth"])
sns.distplot(df["MentalHealth"])

# %%
sns.distplot(df["BMI"])

# %% [markdown]
# __Convert dumy variables__

# %%
df["Diabetic"].value_counts()
# Out:
# No                         269653
# Yes                         40802
# No, borderline diabetes      6781
# Yes (during pregnancy)       2559
# Name: Diabetic, dtype: int64

# %%
_, ax = plt.subplots(1, 2, figsize= (15, 4))
plt.sca(ax[0])
sns.countplot(y = df["GenHealth"], hue=df["Race"])

plt.sca(ax[1])
sns.countplot(df["HeartDisease"], hue=df["Race"])

# %%
_, ax = plt.subplots(1, 2, figsize= (15, 4))
plt.sca(ax[0])
filtered = df[df["Race"] =="Black"].copy()
sns.lineplot(filtered["PhysicalHealth"], filtered["MentalHealth"])
plt.sca(ax[1])
filtered2 = df[df["Race"] =="White"].copy()
sns.lineplot(filtered2["PhysicalHealth"], filtered2["MentalHealth"])

# %%
sns.countplot(df["HeartDisease"], hue=df["DiffWalking"])

# %%
plt.figure(figsize = (10, 5))
sns.countplot(y = df["SleepTime"], hue =  df["HeartDisease"], palette="cool")

# %%
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...
